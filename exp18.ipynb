# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashwini9713/threat-intelligence/blob/main/exp18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Packet Sniffing with Scapy
#
# Scapy is a powerful interactive packet manipulation program. It can forge or decode packets of a wide number of protocols, send them on the wire, capture them, match requests and replies, and much more. It's often used for network discovery, security testing, and network development.
#
# First, we need to install Scapy if it's not already installed. We'll use `pip` for that.

# %%
# Install Scapy
# !pip install scapy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 16.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# Now we can write the code to sniff packets. We'll define a simple function to handle captured packets and then use `sniff()` to start listening for traffic. **Note: Running this code might require administrator/root privileges depending on your environment and operating system.**

# %%
from scapy.all import *

def packet_handler(packet):
    """
    This function will be called for every packet sniffed.
    You can add your custom logic here to process each packet.
    """
    print(f"Captured Packet: {packet.summary()}")
    # You can access different layers of the packet like this:
    # if packet.haslayer(IP):
    #     print(f"  Source IP: {packet[IP].src}")
    #     print(f"  Destination IP: {packet[IP].dst}")
    # if packet.haslayer(TCP):
    #     print(f"  Source Port: {packet[TCP].sport}")
    #     print(f"  Destination Port: {packet[TCP].dport}")

print("Starting packet sniffing... Press Ctrl+C to stop.")

# Sniff 10 packets. You can change 'count' or remove it to sniff indefinitely.
# 'iface' can be used to specify a network interface, e.g., iface='eth0' or iface='Wi-Fi'
# 'prn' is the function to apply to each packet
sniff(prn=packet_handler, count=10)

print("Sniffing finished.")
# Out:
# Starting packet sniffing... Press Ctrl+C to stop.
# Captured Packet: Ether / IP / TCP 172.28.0.12:8080 > 172.28.0.1:55632 PA / Raw
# Captured Packet: Ether / IP / TCP 172.28.0.1:55632 > 172.28.0.12:8080 A
# Captured Packet: Ether / IP / TCP 172.28.0.12:8080 > 172.28.0.1:55632 PA / Raw
# Captured Packet: Ether / IP / TCP 172.28.0.1:55632 > 172.28.0.12:8080 A
# Captured Packet: Ether / IP / TCP 172.28.0.12:8080 > 172.28.0.1:46440 PA / Raw
# Captured Packet: Ether / IP / TCP 172.28.0.1:46440 > 172.28.0.12:8080 A
# Captured Packet: Ether / IP / TCP 172.28.0.1:55632 > 172.28.0.12:8080 PA / Raw
# Captured Packet: Ether / IP / TCP 172.28.0.12:8080 > 172.28.0.1:55632 PA / Raw
# Captured Packet: Ether / IP / TCP 172.28.0.1:55632 > 172.28.0.12:8080 A
# Captured Packet: Ether / IP / TCP 172.28.0.12:8080 > 172.28.0.1:55632 PA / Raw
# Sniffing finished.
